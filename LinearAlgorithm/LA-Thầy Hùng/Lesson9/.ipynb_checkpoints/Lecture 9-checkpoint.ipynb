# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Khai triển SVD

# %%
A=np.array([[4,11,14],[8,7,-2]])
print(A)
# Out:
# [[ 4 11 14]
#  [ 8  7 -2]]

# %%
C=A.T@A
print(C)
# Out:
# [[ 80 100  40]
#  [100 170 140]
#  [ 40 140 200]]

# %%
lam,v=np.linalg.eigh(C)
print(lam.round(3))
print(v.round(3))
# Out:
# [ -0.  90. 360.]
# [[-0.667 -0.667  0.333]
#  [ 0.667 -0.333  0.667]
#  [-0.333  0.667  0.667]]

# %%
u1=A.dot(v[:,2])/np.sqrt(lam[2])
print(u1)
# Out:
# [0.9486833  0.31622777]

# %%
u2=A.dot(v[:,1])/np.sqrt(lam[1])
print(u2)
# Out:
# [ 0.31622777 -0.9486833 ]

# %%
U=np.array([u1,u2])
print(U)
# Out:
# [[ 0.9486833   0.31622777]
#  [ 0.31622777 -0.9486833 ]]

# %%
S=np.sqrt(lam.round(3))
print(S)
# Out:
# [-0.          9.48683298 18.97366596]

# %%
lam1=np.sqrt(lam)
# Out:
# C:\Users\tvlon\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: RuntimeWarning: invalid value encountered in sqrt
#   """Entry point for launching an IPython kernel.

# %%
U
# Out:
# array([[ 0.9486833 ,  0.31622777],
#        [ 0.31622777, -0.9486833 ]])

# %%
V=v.T
V
# Out:
# array([[-0.66666667,  0.66666667, -0.33333333],
#        [-0.66666667, -0.33333333,  0.66666667],
#        [ 0.33333333,  0.66666667,  0.66666667]])

# %%
D=np.zeros(A.shape)

# %%
D[1,1]=np.sqrt(lam1[1])
D[0,0]=np.sqrt(lam1[2])
print(D)
# Out:
# [[4.35587717 0.         0.        ]
#  [0.         3.08007029 0.        ]]

# %%
U@D@V
# Out:
# array([[-3.40423445,  2.4302307 , -0.72811348],
#        [ 1.02970795,  1.89230329, -2.40715726]])

# %%
C=A.dot(A.T) #AA^T
print("AA^T=",C)
# Out:
# AA^T= [[333  81]
#  [ 81 117]]

# %%
lam1,u=np.linalg.eigh(C)
print(lam1)
print(u.round(3))
# Out:
# [ 90. 360.]
# [[ 0.316 -0.949]
#  [-0.949 -0.316]]

# %%
v0=A.T.dot(u[:,0])/np.sqrt(lam1[0])
v1=A.T.dot(u[:,1])/np.sqrt(lam1[1])

# %%
V=np.array([v0,v1])
print(V)
# Out:
# [[-0.66666667 -0.33333333  0.66666667]
#  [-0.33333333 -0.66666667 -0.66666667]]

# %%
S=np.diag(np.sqrt(lam1))
print(S)
# Out:
# [[ 9.48683298  0.        ]
#  [ 0.         18.97366596]]

# %%
u.dot(S.dot(V))
# Out:
# array([[ 4., 11., 14.],
#        [ 8.,  7., -2.]])

# %%
D=A.T.dot(A)
print(D)
# Out:
# [[ 80 100  40]
#  [100 170 140]
#  [ 40 140 200]]

# %%
lam2,v=np.linalg.eigh(D)
print(lam2.round(3))
print(v.round(3))
# Out:
# [ -0.  90. 360.]
# [[-0.667 -0.667  0.333]
#  [ 0.667 -0.333  0.667]
#  [-0.333  0.667  0.667]]

# %%
s1=np.sqrt(lam1[1])
s2=np.sqrt(lam1[0])
Sr=np.diag([s1,s2])
print(Sr)
# Out:
# [[18.97366596  0.        ]
#  [ 0.          9.48683298]]

# %%
r=np.linalg.matrix_rank(A)
print(r)
# Out:
# 2

# %%
Ur=np.array([u[:,1],u[:,0]])
print(Ur)
# Out:
# [[-0.9486833  -0.31622777]
#  [ 0.31622777 -0.9486833 ]]

# %%
Vr=np.array([v[:,2],v[:,1]])
print(Vr)
# Out:
# [[ 0.33333333  0.66666667  0.66666667]
#  [-0.66666667 -0.33333333  0.66666667]]

# %%
#Ur*Sr*Vr^T
Ur.dot(Sr.dot(Vr))
# Out:
# array([[ -4., -11., -14.],
#        [  8.,   7.,  -2.]])

# %%
# SVD
u,s,vt=np.linalg.svd(A)
print("u=",u.round(3))
print("s=",s.round(3))
print("vt=",v.round(3))
# Out:
# u= [[-0.949 -0.316]
#  [-0.316  0.949]]
# s= [18.974  9.487]
# vt= [[-0.333 -0.667 -0.667]
#  [ 0.667  0.333 -0.667]
#  [-0.667  0.667 -0.333]]

# %%
u.dot(np.diag(s).dot(vt[:2]))
# Out:
# array([[ 4., 11., 14.],
#        [ 8.,  7., -2.]])

# %% [markdown]
# ### Khai triển SVD bằng thư viện numpy.linalg.svd

# %%
A=np.array([[2,1,3],[1,2,0]])
print(A)
# Out:
# [[2 1 3]
#  [1 2 0]]

# %%
u,s,v=np.linalg.svd(A)

# %%
u.round(3)
# Out:
# array([[-0.935, -0.355],
#        [-0.355,  0.935]])

# %%
s.round(3)
# Out:
# array([3.94 , 1.865])

# %%
v.round(3)
# Out:
# array([[-0.565, -0.418, -0.712],
#        [ 0.12 ,  0.812, -0.572],
#        [-0.816,  0.408,  0.408]])

# %%
D=np.zeros(A.shape)
D[0,0]=s[0]
D[1,1]=s[1]
print(D)
# Out:
# [[3.93964431 0.         0.        ]
#  [0.         1.8652621  0.        ]]

# %%
A_r=u@D@v
print(A_r.round(3))
# Out:
# [[2. 1. 3.]
#  [1. 2. 0.]]

# %%
np.linalg.pinv(A)
# Out:
# array([[ 0.11111111,  0.11111111],
#        [-0.05555556,  0.44444444],
#        [ 0.27777778, -0.22222222]])

# %%
D=np.diag(s)

# %%
Ad=v.T[:,:2].dot(np.linalg.inv(D).dot(u.T))
print(Ad)
# Out:
# [[ 0.11111111  0.11111111]
#  [-0.05555556  0.44444444]
#  [ 0.27777778 -0.22222222]]

# %%
Ad=1/s[0]*v[0].T.reshape(3,1).dot(u[0].T.reshape(1,2))
+1/s[1]*v[1].T.reshape(3,1).dot(u[1].T.reshape(1,2))
# Out:
# array([[-0.02222222,  0.06666667],
#        [-0.01111111,  0.03333333],
#        [ 0.02222222, -0.06666667]])

# %%
D=np.diag(s)
print(D)
# Out:
# [[18.97366596  0.        ]
#  [ 0.          9.48683298]]

# %%
Ad=v.T[:,:2].dot(np.linalg.inv(D).dot(u.T))
print(Ad)
# Out:
# [[-0.00555556  0.07222222]
#  [ 0.02222222  0.04444444]
#  [ 0.05555556 -0.05555556]]

# %%
np.linalg.pinv(A)
# Out:
# array([[-0.00555556,  0.07222222],
#        [ 0.02222222,  0.04444444],
#        [ 0.05555556, -0.05555556]])

# %%
D=np.zeros(A.shape)
D[0,0]=s[0]
D[1,1]=s[1]
print(D)
# Out:
# [[18.97366596  0.          0.        ]
#  [ 0.          9.48683298  0.        ]]

# %%
u.dot(D.dot(v))
# Out:
# array([[ 4., 11., 14.],
#        [ 8.,  7., -2.]])

# %% [markdown]
# ### Ứng dụng SVD trong phân tích ảnh

# %%
import os
from PIL import Image
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#img = Image.open('test.jpg')
img = Image.open('Lenna.png')

# %%
img.size
# Out:
# (220, 220)

# %%
plt.imshow(img)

# %%
imggray = img.convert('LA')

# %%
plt.imshow(imggray)
plt.show()

# %%
imgmat = np.array( list(imggray.getdata(band = 0)), float)
imgmat.shape = (imggray.size[1], imggray.size[0])
imgmat = np.matrix(imgmat)

# %%
plt.imshow(imgmat, cmap = 'gray')
plt.savefig('Lenna_gray.png')
plt.show()

# %%
print("After compression: ")
U, S, Vt = np.linalg.svd(imgmat) #single value decomposition
# Out:
# After compression:

# %%
k=5
cmpimg = np.matrix(U[:, :k]) * np.diag(S[:k]) * np.matrix(Vt[:k,:])
plt.imshow(cmpimg, cmap = 'gray')
plt.savefig('test_'+str(k)+'.png')
plt.show()

# %%
k=10
cmpimg = np.matrix(U[:, :k]) * np.diag(S[:k]) * np.matrix(Vt[:k,:])
plt.imshow(cmpimg, cmap = 'gray')
plt.savefig('test_'+str(k)+'.png')
plt.show()

# %%
k=25
cmpimg = np.matrix(U[:, :k]) * np.diag(S[:k]) * np.matrix(Vt[:k,:])
plt.imshow(cmpimg, cmap = 'gray')
plt.savefig('test_'+str(k)+'.png')
plt.show()

# %%
k=50
cmpimg = np.matrix(U[:, :k]) * np.diag(S[:k]) * np.matrix(Vt[:k,:])
plt.imshow(cmpimg, cmap = 'gray')
plt.savefig('test_'+str(k)+'.png')
plt.show()

# %%
S.shape
# Out:
# (220,)

# %%
S[:10]
# Out:
# array([27708.15218692,  4552.45853211,  3512.96125996,  2781.96464803,
#         2526.36100432,  2384.56125413,  1970.09729788,  1755.69194665,
#         1448.3566338 ,  1359.25825985])

# %%
plt.plot(S)
plt.savefig('eigenvalues.png')
plt.show()

# %%
plt.plot(S[:5])
plt.savefig('eigen_5.png')
plt.show()

# %%
plt.plot(S[:10])
plt.savefig('eigen_10.png')
plt.show()

# %%
plt.plot(S[:25])
plt.show()

# %%
plt.plot(S[:50])
plt.show()

# %% [markdown]
# # Dữ liệu IRIS

# %%
from sklearn.datasets import load_iris
iris = load_iris()
iris_data = iris.data
iris_target = iris.target

# %%
from sklearn.decomposition import TruncatedSVD
svd = TruncatedSVD(2)
iris_transformed = svd.fit_transform(iris_data)

# %%
plt.figure()
plt.scatter(iris_transformed[:,0],iris_transformed[:,1])
plt.show()

# %% [markdown]
# # Dữ liệu MNIST data sets

# %%
from sklearn import datasets

# %%
#x, y = datasets.fetch_openml('mnist_784', version=1)

# %%
from sklearn.datasets import fetch_openml

# %%
# Load data from https://www.openml.org/d/554
X, y = fetch_openml('mnist_784', version=1, return_X_y=True)

# %%
X.shape
# Out:
# (70000, 784)

# %%
U, S, Vt = np.linalg.svd(X.T)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-68-42cce3d039b0> in <module>
# ----> 1 U, S, Vt = np.linalg.svd(X.T)
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1624
#    1625         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1626         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1627         u = u.astype(result_t, copy=False)
#    1628         s = s.astype(_realType(result_t), copy=False)
#
# MemoryError: Unable to allocate 36.5 GiB for an array with shape (70000, 70000) and data type float64

# %%
A=X.T

# %%
A.shape
# Out:
# (784, 70000)

# %%
U, S, Vt = np.linalg.svd(A)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-71-c6399323bc9a> in <module>
# ----> 1 U, S, Vt = np.linalg.svd(A)
#
# <__array_function__ internals> in svd(*args, **kwargs)
#
# ~\Anaconda3\lib\site-packages\numpy\linalg\linalg.py in svd(a, full_matrices, compute_uv, hermitian)
#    1624
#    1625         signature = 'D->DdD' if isComplexType(t) else 'd->ddd'
# -> 1626         u, s, vh = gufunc(a, signature=signature, extobj=extobj)
#    1627         u = u.astype(result_t, copy=False)
#    1628         s = s.astype(_realType(result_t), copy=False)
#
# MemoryError: Unable to allocate 36.5 GiB for an array with shape (70000, 70000) and data type float64

# %%
C=X.T.dot(X)

# %%
C.shape
# Out:
# (784, 784)

# %%
#np.linalg.eigh(C)

# %%
from sklearn.model_selection import train_test_split
from sklearn.utils import check_random_state

# %%
train_samples = 5000
random_state = check_random_state(0)
permutation = random_state.permutation(X.shape[0])
X = X[permutation]
y = y[permutation]
X = X.reshape((X.shape[0], -1))

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, train_size=train_samples, test_size=10000)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
X_train.shape
# Out:
# (5000, 784)

# %%
A=X_train.T

# %%
img=A[:,0].reshape(28,28)

# %%
img.shape
# Out:
# (28, 28)

# %%
plt.imshow(img)

# %%
U, S, Vt = np.linalg.svd(A)

# %%
k=100
Ak = np.matrix(U[:, :k]) * np.diag(S[:k]) * np.matrix(Vt[:k,:])

# %%
img=Ak[:,0].reshape(28,28)

# %%
plt.imshow(img)
