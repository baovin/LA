# %%
import numpy as np

# %%
from numpy.linalg import inv as inv
from numpy.linalg import pinv as pinv
from numpy.linalg import lstsq as lstsq

# %% [markdown]
# ## Thực hành 1
# Cho $A=\begin{pmatrix}
# 1&-3&-3\\ 1&5&1\\ 1&7&2
# \end{pmatrix}, b=\begin{pmatrix}
# 5\\ -3\\ -5
# \end{pmatrix}$
#
# a) Tính ma trận $A^{\dagger}$.
#
# b) Tìm nghiệm xấp xỉ tốt nhất của hệ $Ax=b$.

# %%
A=np.array([[1,-3,-3],[1,5,1],[1,7,2]])
b=np.array([5,-3,-5])
print('A:=',A)
print('b:=',b)
# Out:
# A:= [[ 1 -3 -3]
#  [ 1  5  1]
#  [ 1  7  2]]
# b:= [ 5 -3 -5]

# %%
pA=pinv(A)
print('Nghich dao suy rong cua A la',pA)
# Out:
# Nghich dao suy rong cua A la [[ 0.21088435  0.08843537  0.05782313]
#  [ 0.04081633  0.08163265  0.09183673]
#  [-0.29591837 -0.09183673 -0.04081633]]

# %%
z=np.dot(pA,b)
print("Nghiệm tốt nhất: ",z)
# Out:
# Nghiệm tốt nhất:  [ 0.5 -0.5 -1. ]

# %% [markdown]
# ## Thực hành 2
# Mô tả nghiệm "tốt nhất" của hệ $$\begin{cases} -x+2y&=4\\ 2x-3y&=1 \\ -x+3y&=2 \end{cases} $$

# %%
A=np.array([[-1,2],[2,-3],[-1,3]])
b=np.array([4,1,2])
print('A:=',A)
print('b:=',b)
z=np.dot(pinv(A),b)
print('z:=',z)
# Out:
# A:= [[-1  2]
#  [ 2 -3]
#  [-1  3]]
# b:= [4 1 2]
# z:= [3. 2.]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
x=np.linspace(-10,10,100)
y1=(4+x)/2
y2=(2*x-1)/3
y3=(2+x)/3

plt.plot(x,y1,c='blue')
plt.plot(x,y2,c='pink')
plt.plot(x,y3,c='green')
plt.plot(z[0],z[1],c='red',marker='o')

plt.show()

# %% [markdown]
# ## Thực hành 3
# Mô tả nghiệm "tốt nhất" của hệ $$\begin{cases} x+y&=1\\ x+y&=2  \end{cases} $$

# %%
A=np.array([[1,1],[1,1]])
b=np.array([1,2])
print('A:=',A)
print('b:=',b)
z=np.dot(pinv(A),b)
print('z:=',z)
# Out:
# A:= [[1 1]
#  [1 1]]
# b:= [1 2]
# z:= [0.75 0.75]

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(6,6))
x=np.linspace(0,2,100)
y1=(1-x)
y2=2-x


plt.plot(x,y1,c='blue')
plt.plot(x,y2,c='pink')
plt.plot(z[0],z[1],c='red',marker='o')

plt.xlim(0,2)
plt.ylim(0,2)
plt.show()
